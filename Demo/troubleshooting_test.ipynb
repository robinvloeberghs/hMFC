# %%
The hMFC is a complex model with many global and local parameters to be estimated. On simulated data the model works great.
However, fitting hMFC on empirical data sometimes results in quirky model behavior.
In this tutorial we’ll discuss how to recognize some potential quirky behavior and how to solve it.
 At the heart of our solution will often be fixing some hyperparameter such that they are not estimated.

# %%
If a0 and all individual a’s go down over iterations:

# %% [markdown]
# ![a0_goes_down.PNG](data:image/png;base64,...)
